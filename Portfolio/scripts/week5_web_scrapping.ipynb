# %% [markdown]
# ## Coding Challenge 5: Web scrapping

# %%
#Importing packages 
import requests     # for making web / API calls
from bs4 import BeautifulSoup   # For parsing the HTML into something we can search

# %%
#Scraping the page
url = 'https://atlas.cid.harvard.edu/growth-projections'
response = requests.get(url)

# %%
response.text
# Out:
# '<!DOCTYPE html><html lang="en"><head><meta charset="utf-8"><title>The Atlas of Economic Complexity</title><meta property="og:title" content="The Atlas of Economic Complexity by @HarvardGrwthLab"><meta property="og:type" content="website"><meta property="og:description" content="Visualize global trade data and economic growth opportunities for every country"><meta property="og:image" content="http://atlas.cid.harvard.edu/static/og/Atlas_logo.png"><script type="text/javascript">if (\'PerformanceObserver\' in window) {\n    var paintObserver = new PerformanceObserver(function (list) {\n      for (const entry of list.getEntries()) {\n          const metricName = entry.name;\n          const time = Math.round(entry.startTime + entry.duration);\n          (window as any).gtag(\'event\', \n            metricName,\n            {\n              \'event_category\': "Performance Metrics",\n              \'event_label\': metricName,\n              \'non_interaction\': true,\n              \'value\': time\n            });\n\n          (window as any).gtag(\'event\', \n            \'timing\',\n            {\n            \'event_category\': \'load\',\n            \'value\': time,\n            \'event_label\': metricName,\n          });\n      }\n    });\n    var longTaskObserver = new PerformanceObserver(function (list) {\n      for (const entry of list.getEntries()) {\n        if (entry.duration > 100) {\n          const value = Math.round(entry.duration);\n          const label = JSON.stringify(entry.attribution);\n\n          (window as any).gtag(\'event\', \n          \'longtask\',\n          {\n            \'event_category\': "Performance Metrics",\n            \'event_label\': label,\n            \'non_interaction\': true,\n            \'value\': value\n          });\n\n        }\n      }\n    });\n    try {\n      paintObserver.observe({entryTypes: [\'paint\']});\n      longTaskObserver.observe({entryTypes: [\'longtask\']});\n    } catch(e) {\n      console.error(e);\n    }\n  }\n\n  if (\'performance\' in window && performance.mark !== undefined) {\n    performance.mark("atlas-page-load");\n  }</script><script async src="https://www.googletagmanager.com/gtag/js?id=G-2ZJTHZQ8JJ"></script><script>function gtag(){dataLayer.push(arguments)}window.dataLayer=window.dataLayer||[],gtag("js",new Date),gtag("config","G-2ZJTHZQ8JJ")</script><script>window.HERO_ELEMENT_NAME="",window.HERO_ELEMENT_NAMES=[]</script><script>try{!function(){if("PerformanceLongTaskTiming"in window){var e=window.__tti={e:[]};e.o=new PerformanceObserver(function(n){e.e=e.e.concat(n.getEntries())}),e.o.observe({entryTypes:["longtask"]})}}()}catch(e){console.error(e)}</script><meta name="viewport" content="width=device-width,initial-scale=1"><link href="/static/app.49afdf47349a7cdbb800.css" rel="stylesheet"><link rel="apple-touch-icon" sizes="57x57" href="/static/icons-d5324b88dee2fe90a2a81a053457a7af/apple-touch-icon-57x57.png"><link rel="apple-touch-icon" sizes="60x60" href="/static/icons-d5324b88dee2fe90a2a81a053457a7af/apple-touch-icon-60x60.png"><link rel="apple-touch-icon" sizes="72x72" href="/static/icons-d5324b88dee2fe90a2a81a053457a7af/apple-touch-icon-72x72.png"><link rel="apple-touch-icon" sizes="76x76" href="/static/icons-d5324b88dee2fe90a2a81a053457a7af/apple-touch-icon-76x76.png"><link rel="apple-touch-icon" sizes="114x114" href="/static/icons-d5324b88dee2fe90a2a81a053457a7af/apple-touch-icon-114x114.png"><link rel="apple-touch-icon" sizes="120x120" href="/static/icons-d5324b88dee2fe90a2a81a053457a7af/apple-touch-icon-120x120.png"><link rel="apple-touch-icon" sizes="144x144" href="/static/icons-d5324b88dee2fe90a2a81a053457a7af/apple-touch-icon-144x144.png"><link rel="apple-touch-icon" sizes="152x152" href="/static/icons-d5324b88dee2fe90a2a81a053457a7af/apple-touch-icon-152x152.png"><link rel="apple-touch-icon" sizes="180x180" href="/static/icons-d5324b88dee2fe90a2a81a053457a7af/apple-touch-icon-180x180.png"><meta name="apple-mobile-web-app-capable" content ...

# %%
# Pass our returned data to the `BeautifulSoup` function.
soup = BeautifulSoup(response.text)

# %%
soup.title
# Out:
# <title>The Atlas of Economic Complexity</title>

# %%
# Use prettify to add formatting and only show the first 1000 characters.
print(soup.prettify()[:1000])
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    The Atlas of Economic Complexity
#   </title>
#   <meta content="The Atlas of Economic Complexity by @HarvardGrwthLab" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Visualize global trade data and economic growth opportunities for every country" property="og:description"/>
#   <meta content="http://atlas.cid.harvard.edu/static/og/Atlas_logo.png" property="og:image"/>
#   <script type="text/javascript">
#    if ('PerformanceObserver' in window) {
#     var paintObserver = new PerformanceObserver(function (list) {
#       for (const entry of list.getEntries()) {
#           const metricName = entry.name;
#           const time = Math.round(entry.startTime + entry.duration);
#           (window as any).gtag('event',
#             metricName,
#             {
#               'event_category': "Performance Metrics",
#               'event_label': metricName,
#               'non_interaction': true,

# %% [markdown]
# By inspecting the page HTML, we can see that the information of interest is contained within XX (`<li>`) element.

# %%
# Select just the
target_div = soup.find('div', class_='answers__listing-left')

articles = target_div.find_all('li')
# Out:
# []
